# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from sqlalchemy import create_engine
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /Users/MX/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/MX/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/MX/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# load data from database
engine = create_engine('sqlite:///InsertDatabaseName.db')

df = pd.read_sql_table('InsertTableName',engine)

X = df['message']
y = df[['related', 'request', 'offer', 'aid_related', 'medical_help', 'medical_products', 'search_and_rescue', 'security', 'military', 'child_alone', 'water', 'food', 'shelter', 'clothing', 'money', 'missing_people', 'refugees', 'death', 'other_aid', 'infrastructure_related', 'transport', 'buildings', 'electricity', 'tools', 'hospitals', 'shops', 'aid_centers', 'other_infrastructure', 'weather_related', 'floods', 'storm', 'fire', 'earthquake', 'cold', 'other_weather', 'direct_report']]

# %%
X.head()
# Out:
# 0    Weather update - a cold front from Cuba that c...
# 1              Is the Hurricane over or is it not over
# 2                      Looking for someone but no name
# 3    UN reports Leogane 80-90 destroyed. Only Hospi...
# 4    says: west side of Haiti, rest of the country ...
# Name: message, dtype: object

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    tokens=word_tokenize(text)
    lemmatizer = WordNetLemmatizer()
    stop_words = stopwords.words("english")
    lemmatized_tokens=[lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
   ('vect',CountVectorizer(tokenizer=tokenize))
    ,('tfidf',TfidfTransformer())
    , ('clf',MultiOutputClassifier(RandomForestClassifier()))
                ])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y)
pipeline.fit(X_train,y_train)
# Out:
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip..._score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=None))])

# %%
y_pred = pipeline.predict(X_test)

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
pred_df=pd.DataFrame(y_pred)
pred_df.columns=y_test.columns
for column in y_test.columns:
    print("Feature: {}".format(column))
    print(classification_report(y_test[column], pred_df[column]))
# Out:
# Feature: related
#               precision    recall  f1-score   support
#
#            0       0.59      0.31      0.41      1517
#            1       0.81      0.93      0.87      5000
#            2       0.50      0.16      0.24        37
#
#    micro avg       0.79      0.79      0.79      6554
#    macro avg       0.64      0.47      0.51      6554
# weighted avg       0.76      0.79      0.76      6554
#
# Feature: request
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      5408
#            1       0.83      0.36      0.50      1146
#
#    micro avg       0.87      0.87      0.87      6554
#    macro avg       0.85      0.67      0.71      6554
# weighted avg       0.87      0.87      0.85      6554
#
# Feature: offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6527
#            1       0.00      0.00      0.00        27
#
#    micro avg       1.00      1.00      1.00      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      1.00      0.99      6554
#
# Feature: aid_related
#               precision    recall  f1-score   support
#
#            0       0.71      0.88      0.79      3831
#            1       0.75      0.49      0.59      2723
#
#    micro avg       0.72      0.72      0.72      6554
#    macro avg       0.73      0.69      0.69      6554
# weighted avg       0.73      0.72      0.71      6554
#
# Feature: medical_help
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      6015
#            1       0.54      0.06      0.11       539
#
#    micro avg       0.92      0.92      0.92      6554
#    macro avg       0.73      0.53      0.53      6554
# weighted avg       0.89      0.92      0.89      6554
#
# Feature: medical_products
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      6239
#            1       0.57      0.04      0.07       315
#
#    micro avg       0.95      0.95      0.95      6554
#    macro avg       0.76      0.52      0.52      6554
# weighted avg       0.94      0.95      0.93      6554
#
# Feature: search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      6367
#            1       0.50      0.02      0.03       187
#
#    micro avg       0.97      0.97      0.97      6554
#    macro avg       0.74      0.51      0.51      6554
# weighted avg       0.96      0.97      0.96      6554
#
# Feature: security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6443
#            1       0.00      0.00      0.00       111
#
#    micro avg       0.98      0.98      0.98      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.97      0.98      0.97      6554
#
# Feature: military
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      6361
#            1       0.90      0.09      0.17       193
#
#    micro avg       0.97      0.97      0.97      6554
#    macro avg       0.94      0.55      0.58      6554
# weighted avg       0.97      0.97      0.96      6554
#
# Feature: child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6554
#
#    micro avg       1.00      1.00      1.00      6554
#    macro avg       1.00      1.00      1.00      6554
# weighted avg       1.00      1.00      1.00      6554
#
# Feature: water
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6142
#            1       0.85      0.21      0.34       412
#
#    micro avg       0.95      0.95      0.95      6554
#    macro avg       0.90      0.61      0.66      6554
# weighted avg       0.94      0.95      0.93      6554
#
# Feature: food
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      5796
#            1       0.82      0.33      0.47       758
#
#    micro avg       0.91      0.91      0.91      6554
#    macro avg       0.87      0.66      0.71      6554
# weighted avg       0.91      0.91      0.90      6554
#
# Feature: shelter
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      5935
#            1       0.85      0.23      0.37       619
#
#    micro avg       0.92      0.92      0.92      6554
#    macro avg       0.89      0.61      0.66      6554
# weighted avg       0.92      0.92      0.90      6554
#
# Feature: clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6458
#            1       0.75      0.06      0.12        96
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.87      0.53      0.55      6554
# weighted avg       0.98      0.99      0.98      6554
#
# Feature: money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6398
#            1       0.71      0.03      0.06       156
#
#    micro avg       0.98      0.98      0.98      6554
#    macro avg       0.85      0.52      0.52      6554
# weighted avg       0.97      0.98      0.97      6554
#
# Feature: missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6471
#            1       1.00      0.01      0.02        83
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.99      0.51      0.51      6554
# weighted avg       0.99      0.99      0.98      6554
#
# Feature: refugees
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6331
#            1       0.50      0.02      0.03       223
#
#    micro avg       0.97      0.97      0.97      6554
#    macro avg       0.73      0.51      0.51      6554
# weighted avg       0.95      0.97      0.95      6554
#
# Feature: death
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6263
#            1       0.83      0.10      0.18       291
#
#    micro avg       0.96      0.96      0.96      6554
#    macro avg       0.89      0.55      0.58      6554
# weighted avg       0.95      0.96      0.94      6554
#
# Feature: other_aid
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      5673
#            1       0.58      0.04      0.07       881
#
#    micro avg       0.87      0.87      0.87      6554
#    macro avg       0.72      0.52      0.50      6554
# weighted avg       0.83      0.87      0.81      6554
#
# Feature: infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      6111
#            1       0.43      0.01      0.01       443
#
#    micro avg       0.93      0.93      0.93      6554
#    macro avg       0.68      0.50      0.49      6554
# weighted avg       0.90      0.93      0.90      6554
#
# Feature: transport
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6254
#            1       0.71      0.14      0.23       300
#
#    micro avg       0.96      0.96      0.96      6554
#    macro avg       0.84      0.57      0.61      6554
# weighted avg       0.95      0.96      0.94      6554
#
# Feature: buildings
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      6225
#            1       0.74      0.09      0.16       329
#
#    micro avg       0.95      0.95      0.95      6554
#    macro avg       0.85      0.54      0.57      6554
# weighted avg       0.94      0.95      0.93      6554
#
# Feature: electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6415
#            1       1.00      0.03      0.06       139
#
#    micro avg       0.98      0.98      0.98      6554
#    macro avg       0.99      0.51      0.52      6554
# weighted avg       0.98      0.98      0.97      6554
#
# Feature: tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6515
#            1       0.00      0.00      0.00        39
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      0.99      0.99      6554
#
# Feature: hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6486
#            1       0.00      0.00      0.00        68
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.98      0.99      0.98      6554
#
# Feature: shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6526
#            1       0.00      0.00      0.00        28
#
#    micro avg       1.00      1.00      1.00      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      1.00      0.99      6554
#
# Feature: aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6470
#            1       0.00      0.00      0.00        84
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.97      0.99      0.98      6554
#
# Feature: other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      6249
#            1       0.14      0.00      0.01       305
#
#    micro avg       0.95      0.95      0.95      6554
#    macro avg       0.55      0.50      0.49      6554
# weighted avg       0.92      0.95      0.93      6554
#
# Feature: weather_related
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      4737
#            1       0.83      0.47      0.60      1817
#
#    micro avg       0.83      0.83      0.83      6554
#    macro avg       0.83      0.72      0.75      6554
# weighted avg       0.83      0.83      0.81      6554
#
# Feature: floods
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      6000
#            1       0.88      0.23      0.37       554
#
#    micro avg       0.93      0.93      0.93      6554
#    macro avg       0.91      0.61      0.67      6554
# weighted avg       0.93      0.93      0.91      6554
#
# Feature: storm
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      5938
#            1       0.77      0.29      0.43       616
#
#    micro avg       0.93      0.93      0.93      6554
#    macro avg       0.85      0.64      0.69      6554
# weighted avg       0.92      0.93      0.91      6554
#
# Feature: fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6494
#            1       0.60      0.05      0.09        60
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.80      0.52      0.54      6554
# weighted avg       0.99      0.99      0.99      6554
#
# Feature: earthquake
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      5960
#            1       0.90      0.61      0.73       594
#
#    micro avg       0.96      0.96      0.96      6554
#    macro avg       0.93      0.80      0.85      6554
# weighted avg       0.96      0.96      0.95      6554
#
# Feature: cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6428
#            1       0.65      0.09      0.15       126
#
#    micro avg       0.98      0.98      0.98      6554
#    macro avg       0.81      0.54      0.57      6554
# weighted avg       0.98      0.98      0.97      6554
#
# Feature: other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6198
#            1       0.63      0.03      0.06       356
#
#    micro avg       0.95      0.95      0.95      6554
#    macro avg       0.79      0.52      0.52      6554
# weighted avg       0.93      0.95      0.92      6554
#
# Feature: direct_report
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91      5244
#            1       0.80      0.30      0.44      1310
#
#    micro avg       0.85      0.85      0.85      6554
#    macro avg       0.83      0.64      0.68      6554
# weighted avg       0.84      0.85      0.82      6554
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
parameters = {
    'clf__estimator__n_estimators':[100,150,200],
                 'clf__estimator__criterion':['gini','entropy'],
                'clf__estimator__max_features':['auto','sqrt','log2']
             }

cv = GridSearchCV(pipeline, param_grid=parameters)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
cv.fit(X_train,y_train)
# Out:
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip..._score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=None))]),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'clf__estimator__n_estimators': [100, 150, 200], 'clf__estimator__criterion': ['gini', 'entropy'], 'clf__estimator__max_features': ['auto', 'sqrt', 'log2']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
y_pred = cv.predict(X_test)

# %%
pred_df=pd.DataFrame(y_pred)
pred_df.columns=y_test.columns
for column in y_test.columns:
    print("Feature: {}".format(column))
    print(classification_report(y_test[column], pred_df[column]))
# Out:
# Feature: related
#               precision    recall  f1-score   support
#
#            0       0.72      0.26      0.38      1517
#            1       0.81      0.97      0.88      5000
#            2       0.86      0.16      0.27        37
#
#    micro avg       0.80      0.80      0.80      6554
#    macro avg       0.79      0.46      0.51      6554
# weighted avg       0.79      0.80      0.76      6554
#
# Feature: request
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94      5408
#            1       0.89      0.44      0.59      1146
#
#    micro avg       0.89      0.89      0.89      6554
#    macro avg       0.89      0.71      0.76      6554
# weighted avg       0.89      0.89      0.88      6554
#
# Feature: offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6527
#            1       0.00      0.00      0.00        27
#
#    micro avg       1.00      1.00      1.00      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      1.00      0.99      6554
#
# Feature: aid_related
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.82      3831
#            1       0.79      0.62      0.69      2723
#
#    micro avg       0.77      0.77      0.77      6554
#    macro avg       0.78      0.75      0.76      6554
# weighted avg       0.77      0.77      0.77      6554
#
# Feature: medical_help
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      6015
#            1       0.66      0.06      0.11       539
#
#    micro avg       0.92      0.92      0.92      6554
#    macro avg       0.79      0.53      0.53      6554
# weighted avg       0.90      0.92      0.89      6554
#
# Feature: medical_products
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      6239
#            1       0.86      0.06      0.11       315
#
#    micro avg       0.95      0.95      0.95      6554
#    macro avg       0.91      0.53      0.54      6554
# weighted avg       0.95      0.95      0.94      6554
#
# Feature: search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      6367
#            1       0.38      0.02      0.03       187
#
#    micro avg       0.97      0.97      0.97      6554
#    macro avg       0.67      0.51      0.51      6554
# weighted avg       0.95      0.97      0.96      6554
#
# Feature: security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6443
#            1       0.00      0.00      0.00       111
#
#    micro avg       0.98      0.98      0.98      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.97      0.98      0.97      6554
#
# Feature: military
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      6361
#            1       0.83      0.08      0.14       193
#
#    micro avg       0.97      0.97      0.97      6554
#    macro avg       0.90      0.54      0.56      6554
# weighted avg       0.97      0.97      0.96      6554
#
# Feature: child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6554
#
#    micro avg       1.00      1.00      1.00      6554
#    macro avg       1.00      1.00      1.00      6554
# weighted avg       1.00      1.00      1.00      6554
#
# Feature: water
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6142
#            1       0.80      0.19      0.31       412
#
#    micro avg       0.95      0.95      0.95      6554
#    macro avg       0.87      0.60      0.64      6554
# weighted avg       0.94      0.95      0.93      6554
#
# Feature: food
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      5796
#            1       0.85      0.42      0.56       758
#
#    micro avg       0.92      0.92      0.92      6554
#    macro avg       0.89      0.71      0.76      6554
# weighted avg       0.92      0.92      0.91      6554
#
# Feature: shelter
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      5935
#            1       0.93      0.23      0.37       619
#
#    micro avg       0.93      0.93      0.93      6554
#    macro avg       0.93      0.61      0.66      6554
# weighted avg       0.93      0.93      0.90      6554
#
# Feature: clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6458
#            1       0.67      0.04      0.08        96
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.83      0.52      0.54      6554
# weighted avg       0.98      0.99      0.98      6554
#
# Feature: money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6398
#            1       0.83      0.03      0.06       156
#
#    micro avg       0.98      0.98      0.98      6554
#    macro avg       0.91      0.52      0.52      6554
# weighted avg       0.97      0.98      0.97      6554
#
# Feature: missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6471
#            1       1.00      0.01      0.02        83
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.99      0.51      0.51      6554
# weighted avg       0.99      0.99      0.98      6554
#
# Feature: refugees
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6331
#            1       0.50      0.02      0.04       223
#
#    micro avg       0.97      0.97      0.97      6554
#    macro avg       0.73      0.51      0.51      6554
# weighted avg       0.95      0.97      0.95      6554
#
# Feature: death
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6263
#            1       0.82      0.11      0.19       291
#
#    micro avg       0.96      0.96      0.96      6554
#    macro avg       0.89      0.55      0.59      6554
# weighted avg       0.95      0.96      0.94      6554
#
# Feature: other_aid
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      5673
#            1       0.69      0.01      0.02       881
#
#    micro avg       0.87      0.87      0.87      6554
#    macro avg       0.78      0.51      0.48      6554
# weighted avg       0.84      0.87      0.81      6554
#
# Feature: infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      6111
#            1       0.00      0.00      0.00       443
#
#    micro avg       0.93      0.93      0.93      6554
#    macro avg       0.47      0.50      0.48      6554
# weighted avg       0.87      0.93      0.90      6554
#
# Feature: transport
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6254
#            1       0.76      0.11      0.20       300
#
#    micro avg       0.96      0.96      0.96      6554
#    macro avg       0.86      0.56      0.59      6554
# weighted avg       0.95      0.96      0.94      6554
#
# Feature: buildings
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      6225
#            1       0.87      0.10      0.18       329
#
#    micro avg       0.95      0.95      0.95      6554
#    macro avg       0.91      0.55      0.58      6554
# weighted avg       0.95      0.95      0.94      6554
#
# Feature: electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6415
#            1       0.83      0.04      0.07       139
#
#    micro avg       0.98      0.98      0.98      6554
#    macro avg       0.91      0.52      0.53      6554
# weighted avg       0.98      0.98      0.97      6554
#
# Feature: tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6515
#            1       0.00      0.00      0.00        39
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      0.99      0.99      6554
#
# Feature: hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6486
#            1       0.00      0.00      0.00        68
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.98      0.99      0.98      6554
#
# Feature: shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6526
#            1       0.00      0.00      0.00        28
#
#    micro avg       1.00      1.00      1.00      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      1.00      0.99      6554
#
# Feature: aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6470
#            1       0.00      0.00      0.00        84
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.97      0.99      0.98      6554
#
# Feature: other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      6249
#            1       0.00      0.00      0.00       305
#
#    micro avg       0.95      0.95      0.95      6554
#    macro avg       0.48      0.50      0.49      6554
# weighted avg       0.91      0.95      0.93      6554
#
# Feature: weather_related
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91      4737
#            1       0.87      0.56      0.68      1817
#
#    micro avg       0.85      0.85      0.85      6554
#    macro avg       0.86      0.76      0.79      6554
# weighted avg       0.86      0.85      0.84      6554
#
# Feature: floods
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6000
#            1       0.92      0.37      0.53       554
#
#    micro avg       0.94      0.94      0.94      6554
#    macro avg       0.93      0.68      0.75      6554
# weighted avg       0.94      0.94      0.93      6554
#
# Feature: storm
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      5938
#            1       0.84      0.37      0.51       616
#
#    micro avg       0.93      0.93      0.93      6554
#    macro avg       0.89      0.68      0.74      6554
# weighted avg       0.93      0.93      0.92      6554
#
# Feature: fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6494
#            1       0.00      0.00      0.00        60
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.98      0.99      0.99      6554
#
# Feature: earthquake
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      5960
#            1       0.90      0.69      0.78       594
#
#    micro avg       0.97      0.97      0.97      6554
#    macro avg       0.94      0.84      0.88      6554
# weighted avg       0.96      0.97      0.96      6554
#
# Feature: cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6428
#            1       0.80      0.06      0.12       126
#
#    micro avg       0.98      0.98      0.98      6554
#    macro avg       0.89      0.53      0.55      6554
# weighted avg       0.98      0.98      0.97      6554
#
# Feature: other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6198
#            1       0.50      0.01      0.03       356
#
#    micro avg       0.95      0.95      0.95      6554
#    macro avg       0.72      0.51      0.50      6554
# weighted avg       0.92      0.95      0.92      6554
#
# Feature: direct_report
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92      5244
#            1       0.87      0.36      0.51      1310
#
#    micro avg       0.86      0.86      0.86      6554
#    macro avg       0.86      0.67      0.71      6554
# weighted avg       0.86      0.86      0.84      6554
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

pipeline = Pipeline([
   ('vect',TfidfVectorizer(tokenizer=tokenize))
    ,('tfidf',TfidfTransformer())
    , ('clf',MultiOutputClassifier(RandomForestClassifier()))
                ])

# %%
parameters = {
    'clf__estimator__n_estimators':[100,150,200],
                 'clf__estimator__criterion':['gini','entropy'],
                'clf__estimator__max_features':['auto','sqrt','log2']
             }

cv = GridSearchCV(pipeline, param_grid=parameters)

# %%
cv.fit(X_train,y_train)
# Out:
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('vect', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
# ..._score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=None))]),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'clf__estimator__n_estimators': [100, 150, 200], 'clf__estimator__criterion': ['gini', 'entropy'], 'clf__estimator__max_features': ['auto', 'sqrt', 'log2']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
y_pred = cv.predict(X_test)

# %%
pred_df=pd.DataFrame(y_pred)
pred_df.columns=y_test.columns
for column in y_test.columns:
    print("Feature: {}".format(column))
    print(classification_report(y_test[column], pred_df[column]))
# Out:
# Feature: related
#               precision    recall  f1-score   support
#
#            0       0.71      0.25      0.37      1517
#            1       0.81      0.97      0.88      5000
#            2       0.78      0.19      0.30        37
#
#    micro avg       0.80      0.80      0.80      6554
#    macro avg       0.77      0.47      0.52      6554
# weighted avg       0.78      0.80      0.76      6554
#
# Feature: request
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      5408
#            1       0.89      0.47      0.61      1146
#
#    micro avg       0.90      0.90      0.90      6554
#    macro avg       0.89      0.73      0.78      6554
# weighted avg       0.90      0.90      0.88      6554
#
# Feature: offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6527
#            1       0.00      0.00      0.00        27
#
#    micro avg       1.00      1.00      1.00      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      1.00      0.99      6554
#
# Feature: aid_related
#               precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82      3831
#            1       0.79      0.63      0.70      2723
#
#    micro avg       0.78      0.78      0.78      6554
#    macro avg       0.78      0.76      0.76      6554
# weighted avg       0.78      0.78      0.77      6554
#
# Feature: medical_help
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      6015
#            1       0.66      0.05      0.09       539
#
#    micro avg       0.92      0.92      0.92      6554
#    macro avg       0.79      0.52      0.52      6554
# weighted avg       0.90      0.92      0.89      6554
#
# Feature: medical_products
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      6239
#            1       0.71      0.06      0.12       315
#
#    micro avg       0.95      0.95      0.95      6554
#    macro avg       0.83      0.53      0.55      6554
# weighted avg       0.94      0.95      0.93      6554
#
# Feature: search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      6367
#            1       0.50      0.02      0.04       187
#
#    micro avg       0.97      0.97      0.97      6554
#    macro avg       0.74      0.51      0.51      6554
# weighted avg       0.96      0.97      0.96      6554
#
# Feature: security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6443
#            1       0.00      0.00      0.00       111
#
#    micro avg       0.98      0.98      0.98      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.97      0.98      0.97      6554
#
# Feature: military
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      6361
#            1       0.87      0.07      0.12       193
#
#    micro avg       0.97      0.97      0.97      6554
#    macro avg       0.92      0.53      0.56      6554
# weighted avg       0.97      0.97      0.96      6554
#
# Feature: child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6554
#
#    micro avg       1.00      1.00      1.00      6554
#    macro avg       1.00      1.00      1.00      6554
# weighted avg       1.00      1.00      1.00      6554
#
# Feature: water
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6142
#            1       0.79      0.23      0.35       412
#
#    micro avg       0.95      0.95      0.95      6554
#    macro avg       0.87      0.61      0.66      6554
# weighted avg       0.94      0.95      0.93      6554
#
# Feature: food
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      5796
#            1       0.87      0.40      0.55       758
#
#    micro avg       0.92      0.92      0.92      6554
#    macro avg       0.90      0.70      0.75      6554
# weighted avg       0.92      0.92      0.91      6554
#
# Feature: shelter
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      5935
#            1       0.91      0.22      0.35       619
#
#    micro avg       0.92      0.92      0.92      6554
#    macro avg       0.92      0.61      0.66      6554
# weighted avg       0.92      0.92      0.90      6554
#
# Feature: clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6458
#            1       0.83      0.05      0.10        96
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.91      0.53      0.55      6554
# weighted avg       0.98      0.99      0.98      6554
#
# Feature: money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6398
#            1       0.83      0.03      0.06       156
#
#    micro avg       0.98      0.98      0.98      6554
#    macro avg       0.91      0.52      0.52      6554
# weighted avg       0.97      0.98      0.97      6554
#
# Feature: missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6471
#            1       1.00      0.01      0.02        83
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.99      0.51      0.51      6554
# weighted avg       0.99      0.99      0.98      6554
#
# Feature: refugees
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6331
#            1       0.44      0.02      0.03       223
#
#    micro avg       0.97      0.97      0.97      6554
#    macro avg       0.71      0.51      0.51      6554
# weighted avg       0.95      0.97      0.95      6554
#
# Feature: death
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6263
#            1       0.78      0.12      0.21       291
#
#    micro avg       0.96      0.96      0.96      6554
#    macro avg       0.87      0.56      0.60      6554
# weighted avg       0.95      0.96      0.95      6554
#
# Feature: other_aid
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      5673
#            1       0.64      0.01      0.02       881
#
#    micro avg       0.87      0.87      0.87      6554
#    macro avg       0.75      0.50      0.47      6554
# weighted avg       0.84      0.87      0.81      6554
#
# Feature: infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      6111
#            1       0.00      0.00      0.00       443
#
#    micro avg       0.93      0.93      0.93      6554
#    macro avg       0.47      0.50      0.48      6554
# weighted avg       0.87      0.93      0.90      6554
#
# Feature: transport
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6254
#            1       0.77      0.11      0.19       300
#
#    micro avg       0.96      0.96      0.96      6554
#    macro avg       0.86      0.55      0.59      6554
# weighted avg       0.95      0.96      0.94      6554
#
# Feature: buildings
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      6225
#            1       0.82      0.09      0.15       329
#
#    micro avg       0.95      0.95      0.95      6554
#    macro avg       0.89      0.54      0.57      6554
# weighted avg       0.95      0.95      0.93      6554
#
# Feature: electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6415
#            1       0.60      0.02      0.04       139
#
#    micro avg       0.98      0.98      0.98      6554
#    macro avg       0.79      0.51      0.52      6554
# weighted avg       0.97      0.98      0.97      6554
#
# Feature: tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6515
#            1       0.00      0.00      0.00        39
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      0.99      0.99      6554
#
# Feature: hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6486
#            1       0.00      0.00      0.00        68
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.98      0.99      0.98      6554
#
# Feature: shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6526
#            1       0.00      0.00      0.00        28
#
#    micro avg       1.00      1.00      1.00      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      1.00      0.99      6554
#
# Feature: aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6470
#            1       0.00      0.00      0.00        84
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.97      0.99      0.98      6554
#
# Feature: other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      6249
#            1       0.00      0.00      0.00       305
#
#    micro avg       0.95      0.95      0.95      6554
#    macro avg       0.48      0.50      0.49      6554
# weighted avg       0.91      0.95      0.93      6554
#
# Feature: weather_related
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91      4737
#            1       0.87      0.59      0.71      1817
#
#    micro avg       0.86      0.86      0.86      6554
#    macro avg       0.86      0.78      0.81      6554
# weighted avg       0.86      0.86      0.85      6554
#
# Feature: floods
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      6000
#            1       0.90      0.34      0.50       554
#
#    micro avg       0.94      0.94      0.94      6554
#    macro avg       0.92      0.67      0.73      6554
# weighted avg       0.94      0.94      0.93      6554
#
# Feature: storm
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      5938
#            1       0.83      0.39      0.53       616
#
#    micro avg       0.94      0.94      0.94      6554
#    macro avg       0.88      0.69      0.75      6554
# weighted avg       0.93      0.94      0.92      6554
#
# Feature: fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6494
#            1       0.00      0.00      0.00        60
#
#    micro avg       0.99      0.99      0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.98      0.99      0.99      6554
#
# Feature: earthquake
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      5960
#            1       0.90      0.70      0.79       594
#
#    micro avg       0.97      0.97      0.97      6554
#    macro avg       0.94      0.85      0.88      6554
# weighted avg       0.96      0.97      0.96      6554
#
# Feature: cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6428
#            1       0.79      0.09      0.16       126
#
#    micro avg       0.98      0.98      0.98      6554
#    macro avg       0.88      0.54      0.57      6554
# weighted avg       0.98      0.98      0.97      6554
#
# Feature: other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6198
#            1       0.50      0.01      0.03       356
#
#    micro avg       0.95      0.95      0.95      6554
#    macro avg       0.72      0.51      0.50      6554
# weighted avg       0.92      0.95      0.92      6554
#
# Feature: direct_report
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      5244
#            1       0.86      0.38      0.53      1310
#
#    micro avg       0.86      0.86      0.86      6554
#    macro avg       0.86      0.68      0.73      6554
# weighted avg       0.86      0.86      0.84      6554
# /Users/MX/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
import pickle
filename = 'finalized_model.sav'
pickle.dump(cv, open(filename, 'wb'))

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
